# %% [markdown]
# #Do adult and senior dogs spend more average time on Petfinder than baby or young dogs in Georgia?

# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
# read in CSV
dogs_df = pd.read_csv('dogs_clean.csv')

# %%
# preview dataframe
dogs_df.head()
# Out:
#      Pet ID                 Name     Status Publish Date Organization ID  \
# 0  54858447                 Boon  adoptable   2022-03-04           GA862
# 1  54802620               Casper  adoptable   2022-03-01            GA99
# 2  55368350  Giacomo (In Foster)  adoptable   2022-04-22           GA335
# 3  55179362                 Loki  adoptable   2022-04-01           GA340
# 4  55331643                Queen  adoptable   2022-04-18           GA217
#
#       City State               Breed    Age  Gender    Size  \
# 0   Athens    GA         Mixed Breed  Adult    Male   Large
# 1    Macon    GA         Mixed Breed  Young    Male  Medium
# 2  Atlanta    GA         Mixed Breed  Young    Male   Small
# 3   Tucker    GA  Labrador Retriever  Adult    Male   Large
# 4  Atlanta    GA    Pit Bull Terrier  Young  Female  Medium
#
#    Spayed or Neutered  House Trained  Special Needs  Shots Current  \
# 0                True          False          False          False
# 1                True          False          False          False
# 2                True          False          False          False
# 3                True           True           True           True
# 4               False          False          False          False
#
#   Date Collected  Days Available
# 0     2022-04-26              53
# 1     2022-04-26              56
# 2     2022-04-26               4
# 3     2022-04-26              25
# 4     2022-04-26               8

# %%
#Look at distribution of dog sizes
dogs_df['Size'].value_counts()
# Out:
# Large          371
# Medium         358
# Small           92
# Extra Large     11
# Name: Size, dtype: int64

# %%
#Using the aggregation method, look at average 
initial_stats = dogs_df.groupby(['Size'])['Days Available'].agg(['mean', 'median', 'var', 'std','sem'])
initial_stats
# Out:
#                    mean  median            var         std         sem
# Size
# Extra Large  653.272727   406.0  772301.218182  878.806701  264.970190
# Large        120.811321    52.0  110075.234574  331.775880   17.224945
# Medium       128.438547    33.0  143039.888370  378.206145   19.988816
# Small         93.750000    13.0   96624.739011  310.845201   32.407852

# %%
#Generate a bar plot showing the days vs avg size
total_days = dogs_df.groupby(['Size'])['Days Available'].mean()
bar_plot = total_days.sort_values(ascending=False).plot(kind='bar')

# Set the xlabel, ylabel, and title
bar_plot.set_ylabel("Total Number of Days Available")
bar_plot.set_title("Total Number of Days Available for each Dog Size")
plt.show()

# %%
#Generate a box plot showing the days vs size
avg_days = []

size_list = ['Extra Large', 'Large','Medium','Small']

for each in size_list:
    #use loc to find the rows corresponding to each
    days = dogs_df.loc[dogs_df['Size']==each]['Days Available']
    avg_days.append(days)
    print(each)
# Out:
# Extra Large
# Large
# Medium
# Small

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax = plt.subplots(figsize=(9,7))
ax.set_title('Days Available')
ax.set_xlabel('Size')
ax.set_ylabel('Days')
ax.boxplot(avg_days,notch=0,sym='gD')
plt.xticks([1,2,3,4],size_list)

# Save the figure

plt.show()

# %%
#There are only a small number of "Extra Large" dogs. 
#This small sample size could be skewing the data.
#Modify grouping lists to be either big (Extra large and Large) or small (Medium and Small).

#create a new dataframe for dogs_df
dogs_df2 = dogs_df

size_group_df ={
    "Extra Large":"Big",
    "Large": "Big",
    "Medium":"Small",
    "Small":"Small"
}

dogs_df2['Group']=dogs_df2['Size'].map(size_group_df)
dogs_df2
# Out:
#        Pet ID                  Name     Status Publish Date Organization ID  \
# 0    54858447                  Boon  adoptable   2022-03-04           GA862
# 1    54802620                Casper  adoptable   2022-03-01            GA99
# 2    55368350   Giacomo (In Foster)  adoptable   2022-04-22           GA335
# 3    55179362                  Loki  adoptable   2022-04-01           GA340
# 4    55331643                 Queen  adoptable   2022-04-18           GA217
# ..        ...                   ...        ...          ...             ...
# 827  54255555  Aphrodite- In Foster  adoptable   2022-01-16           GA423
# 828  55192469         Stuart Wiggle  adoptable   2022-04-03           GA217
# 829  55304165                 Chica  adoptable   2022-04-14           GA862
# 830  55304095                  Lana  adoptable   2022-04-14           GA862
# 831  54459136        Mitch (Run 40)  adoptable   2022-01-31           GA733
#
#          City State               Breed    Age  Gender    Size  \
# 0      Athens    GA         Mixed Breed  Adult    Male   Large
# 1       Macon    GA         Mixed Breed  Young    Male  Medium
# 2     Atlanta    GA         Mixed Breed  Young    Male   Small
# 3      Tucker    GA  Labrador Retriever  Adult    Male   Large
# 4     Atlanta    GA    Pit Bull Terrier  Young  Female  Medium
# ..        ...   ...                 ...    ...     ...     ...
# 827  Chamblee    GA         Mixed Breed  Adult  Female   Large
# 828   Atlanta    GA     Black Mouth Cur   Baby    Male   Small
# 829    Athens    GA         Mixed Breed  Young  Female  Medium
# 830    Athens    GA         Mixed Breed  Adult  Female   Large
# 831  Columbus    GA         Mixed Breed  Adult    Male   Large
#
#      Spayed or Neutered  House Trained  Special Needs  Shots Current  \
# 0                  True          False          False          False
# 1                  True          False          False          False
# 2                  True          False          False          False
# 3                  True           True           True           True
# 4                 False          False          False          False
# ..                  ...            ...            ...            ...
# 827                True          False          False          False
# 828                True          False          False          False
# 829               False          False          False          False
# 830               False          False          False          False
# 831                True          False          False           True
#
#     Date Collected  Days Available  Group
# 0       2022-04-26              53    Big
# 1       2022-04-26              56  Small
# 2       2022-04-26               4  Small
# 3       2022-04-26              25    Big
# 4       2022-04-26               8  Small
# ..             ...             ...    ...
# 827     2022-04-26             100    Big
# 828     2022-04-26              23  Small
# 829     2022-04-26              12  Small
# 830     2022-04-26              12    Big
# 831     2022-04-26              85    Big
#
# [832 rows x 18 columns]

# %%
#Using the aggregation method, look at average with new grouping 
new_stats = dogs_df2.groupby(['Group'])['Days Available'].agg(['mean', 'median', 'var', 'std','sem'])
new_stats
# Out:
#              mean  median            var         std        sem
# Group
# Big    136.143979    52.5  135117.351919  367.583122  18.807189
# Small  121.346667    29.0  133510.382895  365.390726  17.224684

# %%
#Generate a bar plot showing the days vs avg size
total_days = dogs_df2.groupby(['Group'])['Days Available'].mean()
bar_plot = total_days.sort_values(ascending=False).plot(kind='bar')

# Set the xlabel, ylabel, and title
bar_plot.set_ylabel("Total Number of Days Available")
bar_plot.set_title("Total Number of Days Available for each Dog Size")
plt.show()

# %%
#Generate a box plot showing the days vs size
avg_days2 = []

size_list2 = ['Big','Small']

for each in size_list2:
    #use loc to find the rows corresponding to each
    days = dogs_df2.loc[dogs_df2['Group']==each]['Days Available']
    avg_days2.append(days)
    print(each)
# Out:
# Big
# Small

# %%
# Generate a box plot
fig1, ax = plt.subplots(figsize=(9,7))
ax.set_title('Days Available')
ax.set_xlabel('Size')
ax.set_ylabel('Days')
ax.boxplot(avg_days2,notch=0,sym='gD')
plt.xticks([1,2],size_list2)

# Save the figure

plt.show()
